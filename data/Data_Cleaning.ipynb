# %%
import pickle
import pandas as pd

# %%
with open('./pickles/Total_DF_2017.p', 'rb') as read_file:
    df_2017=pickle.load(read_file)

# %%
df_2017.head()
# Out:
#                 name  Age_Age  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0     Todd Gurley II     26.0              279           1305
# 1       Le'Veon Bell     28.5              321           1291
# 2       Alvin Kamara     25.1              120            728
# 3        Kareem Hunt     25.0              272           1327
# 4  Melvin Gordon III     27.3              284           1105
#
#    Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0              4.7              13                  87                 64
# 1              4.0               9                 106                 85
# 2              6.1               8                 101                 82
# 3              4.9               8                  63                 53
# 4              3.9               8                  83                 58
#
#    Receiving_YDS_x_x  Receiving_TD_x_x  ... Receiving_TD_y_y Fumbles_FUM_y  \
# ...

# %%
with open('./pickles/Total_DF_2018.p', 'rb') as read_file:
    df_2018=pickle.load(read_file)

# %%
df_2018.head()
# Out:
#                   name  Age_x  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0  Christian McCaffrey   24.2              219           1098
# 1       Saquon Barkley   23.5              261           1307
# 2       Todd Gurley II   26.0              256           1251
# 3         Alvin Kamara   25.1              194            883
# 4      Ezekiel Elliott   25.1              304           1435
#
#    Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0              5.0               7                 124                107
# 1              5.0              11                 121                 91
# 2              4.9              17                  81                 59
# 3              4.6              14                 105                 81
# 4              4.7               6                  95                 77
#
#    Receiving_YDS_x_x  Receiving_TD_x_x  ... Receiving_TD_y_y Fumbles_FUM_y  \
# ...

# %%
with open('./pickles/Total_DF_2019.p', 'rb') as read_file:
    df_2019=pickle.load(read_file)

# %%
df_2019.head()
# Out:
#                   name  Age_x  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0  Christian McCaffrey   24.2              287           1387
# 1          Aaron Jones   25.7              236           1084
# 2      Ezekiel Elliott   25.1              301           1357
# 3        Austin Ekeler   25.3              132            557
# 4          Dalvin Cook   25.0              250           1135
#
#    Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0              4.8              15                 143                116
# 1              4.6              16                  69                 49
# 2              4.5              12                  72                 54
# 3              4.2               3                 108                 92
# 4              4.5              13                  63                 53
#
#    Receiving_YDS_x_x  Receiving_TD_x_x  ... Receiving_TD_y_y Fumbles_FUM_y  \
# ...

# %%
#Add year

df_2017=df_2017.assign(Year='2017')

# %%
df_2017
# Out:
#                  name  Age_Age  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0      Todd Gurley II     26.0              279           1305
# 1        Le'Veon Bell     28.5              321           1291
# 2        Alvin Kamara     25.1              120            728
# 3         Kareem Hunt     25.0              272           1327
# 4   Melvin Gordon III     27.3              284           1105
# ..                ...      ...              ...            ...
# 67         Eddie Lacy     29.6               69            179
# 68       Paul Perkins     25.8               41             90
# 69     Branden Oliver     29.3               35             83
# 70        Terron Ward     28.5               30            129
# 71       James Conner     25.3               32            144
#
#     Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0               4.7              13                  87                 64
# ...

# %%
df_2018=df_2018.assign(Year='2018')

# %%
df_2018
# Out:
#                    name  Age_x  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0   Christian McCaffrey   24.2              219           1098
# 1        Saquon Barkley   23.5              261           1307
# 2        Todd Gurley II   26.0              256           1251
# 3          Alvin Kamara   25.1              194            883
# 4       Ezekiel Elliott   25.1              304           1435
# ..                  ...    ...              ...            ...
# 86        Marcus Murphy   28.9               52            250
# 87       Raheem Mostert   28.4               34            261
# 88        Malcolm Brown   27.3               43            212
# 89            Rod Smith   28.6               44            127
# 90   DeAndre Washington   27.5               30            115
#
#     Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0               5.0               7                 124                107
# ...

# %%
df_2019=df_2019.assign(Year='2019')

# %%
df_2019
# Out:
#                      name  Age_x  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0     Christian McCaffrey   24.2              287           1387
# 1             Aaron Jones   25.7              236           1084
# 2         Ezekiel Elliott   25.1              301           1357
# 3           Austin Ekeler   25.3              132            557
# 4             Dalvin Cook   25.0              250           1135
# ..                    ...    ...              ...            ...
# 74      Jonathan Williams   26.5               49            235
# 75           Bilal Powell   31.8               59            229
# 76          Ty Montgomery   27.6               32            103
# 77        Darwin Thompson   23.5               38            128
# 78  Darrell Henderson Jr.   23.0               39            147
#
#     Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0               4.8              15                 143                116
# ...

# %%
list(df_2017.columns)
# Out:
# ['name',
#  'Age_Age',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'SnapShare_SnapShare',
#  'OppShare_OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'VS. FORMATION / FRONT_AVG BOX',
#  'VS. FORMATION / FRONT_STACKED',
#  'VS. FORMATION / FRONT_BASE',
#  'VS. FORMATION / FRONT_LIGHT',
#  'Rushing_ATT_y_x',
#  'Rushing_YDS_y_x',
#  'Rushing_AVG_y_x',
#  'Rushing_TD_y_x',
#  'Receiving_TGTS_y_x',
#  'Receiving_REC_y_x',
#  'Receiving_YDS_y_x',
#  'Receiving_TD_y_x',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Rushing_ATT_x_y',
#  'Rushing_AVG_x_y',
#  'Rushing_TD_x_y',
#  'Receiving_TGTS_x_y',
#  'Receiving_REC_x_y',
#  'Receiving_YDS_x_y',
# ...

# %%
df_2017.Rushing_ATT_x_x #Full Game
# Out:
# 0     279
# 1     321
# 2     120
# 3     272
# 4     284
#      ...
# 67     69
# 68     41
# 69     35
# 70     30
# 71     32
# Name: Rushing_ATT_x_x, Length: 72, dtype: int64

# %%
df_2017.Rushing_ATT_y_x #Full Game Drop
# Out:
# 0     279
# 1     321
# 2     120
# 3     272
# 4     284
#      ...
# 67     69
# 68     41
# 69     35
# 70     30
# 71     32
# Name: Rushing_ATT_y_x, Length: 72, dtype: int64

# %%
df_2017.Rushing_ATT_x_y #Full Game Drop
# Out:
# 0     279
# 1     321
# 2     120
# 3     272
# 4     284
#      ...
# 67     69
# 68     41
# 69     35
# 70     30
# 71     32
# Name: Rushing_ATT_x_y, Length: 72, dtype: int64

# %%
df_2017.Rushing_ATT_y_y #RZ
# Out:
# 0     63
# 1     63
# 2     25
# 3     37
# 4     49
#       ..
# 67     7
# 68     5
# 69     2
# 70     5
# 71     4
# Name: Rushing_ATT_y_y, Length: 72, dtype: int64

# %%
df_2017=df_2017.drop(columns=['Rushing_ATT_y_x',
 'Rushing_YDS_y_x',
 'Rushing_AVG_y_x',
 'Rushing_TD_y_x',
 'Receiving_TGTS_y_x',
 'Receiving_REC_y_x',
 'Receiving_YDS_y_x',
 'Receiving_TD_y_x',
 'Rushing_ATT_x_y',
 'Rushing_AVG_x_y',
 'Rushing_TD_x_y',
 'Receiving_TGTS_x_y',
 'Receiving_REC_x_y',
 'Receiving_YDS_x_y',
 'Receiving_TD_x_y',])

# %%
list(df_2017.columns)
# Out:
# ['name',
#  'Age_Age',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'SnapShare_SnapShare',
#  'OppShare_OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'VS. FORMATION / FRONT_AVG BOX',
#  'VS. FORMATION / FRONT_STACKED',
#  'VS. FORMATION / FRONT_BASE',
#  'VS. FORMATION / FRONT_LIGHT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_AVG_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
# ...

# %%
df_2017.PPG_x
# Out:
# 0     25.6
# 1     22.8
# 2     19.6
# 3     18.4
# 4     18.0
#       ...
# 67     3.2
# 68     2.0
# 69     2.1
# 70     1.1
# 71     1.0
# Name: PPG_x, Length: 72, dtype: float64

# %%
df_2017.PPG_y
# Out:
# 0     8.1
# 1     6.3
# 2     6.0
# 3     3.7
# 4     5.7
#      ...
# 67    0.1
# 68    0.1
# 69    0.1
# 70    0.1
# 71    0.1
# Name: PPG_y, Length: 72, dtype: float64

# %%
df_2017=df_2017.drop(columns='Age')

# %%
list(df_2017.columns)
# Out:
# ['name',
#  'Age_Age',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'SnapShare_SnapShare',
#  'OppShare_OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'VS. FORMATION / FRONT_AVG BOX',
#  'VS. FORMATION / FRONT_STACKED',
#  'VS. FORMATION / FRONT_BASE',
#  'VS. FORMATION / FRONT_LIGHT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_AVG_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
# ...

# %%
df_2017=df_2017.drop(columns='Rushing_AVG_y_y')

# %%
list(df_2017.columns)
# Out:
# ['name',
#  'Age_Age',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'SnapShare_SnapShare',
#  'OppShare_OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'VS. FORMATION / FRONT_AVG BOX',
#  'VS. FORMATION / FRONT_STACKED',
#  'VS. FORMATION / FRONT_BASE',
#  'VS. FORMATION / FRONT_LIGHT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Pos_rk',
# ...

# %%
df_2017.Fumbles_FUM_x
# Out:
# 0     5
# 1     3
# 2     1
# 3     1
# 4     1
#      ..
# 67    0
# 68    0
# 69    0
# 70    1
# 71    0
# Name: Fumbles_FUM_x, Length: 72, dtype: int64

# %%
df_2017.Fumbles_FUM_y
# Out:
# 0     1
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 67    0
# 68    0
# 69    0
# 70    0
# 71    0
# Name: Fumbles_FUM_y, Length: 72, dtype: int64

# %%
df_2017=df_2017.rename(columns={'name': 'Name',
 'Age_Age': 'Age',
 'Rushing_ATT_x_x': 'FF_Rush_Att',
 'Rushing_YDS_x': 'FF_Rush_Yds',
 'Rushing_AVG_x_x': 'FF_Ypc',
 'Rushing_TD_x_x': 'FF_Rush_TD',
 'Receiving_TGTS_x_x': 'FF_Rec_Tgt',
 'Receiving_REC_x_x': 'FF_Rec',
 'Receiving_YDS_x_x': 'FF_Rec_Yds',
 'Receiving_TD_x_x': 'FF_Rec_TD',
 'SnapShare_SnapShare': 'Snapshare',
 'OppShare_OppShare': 'Opp_Share',
 #'Shotgun_PCT',
 #'Shotgun_YPC',
 #'Under Center_PCT',
 #'Under Center_YPC',
 'VS. FORMATION / FRONT_AVG BOX': 'Box_Front',
 'VS. FORMATION / FRONT_STACKED': 'Stacked_Front',
 'VS. FORMATION / FRONT_BASE': 'Base_Front',
 'VS. FORMATION / FRONT_LIGHT': 'Light_Front',
 #'JukeRate',
 #'Tck_Evad',
 #'Tot_Yds_Ctd',
 #'Yds_Ctd_GM',
 #'Breakaway_TOT',
 #'Breakaway_Rate',
 #'Fan_Pts_Att',
 #'Fan_Pts_Tgt',
 #'Fan_Pts_Opp',
 #'Tot_Dps',
 #'Drops_Rate',
 'Fumbles_FUM_x': 'FF_Fum',
 'Fumbles_LST_x': 'FF_Fum_Lst',
 'PPG_x': 'FF_PPG',
 'FPTS_x': 'FF_FPTS',
 #'GMS',
 'Rushing_ATT_y_y': 'RZ_Rush_Att',
 'Rushing_YDS_y_y': 'RZ_Rush_Yds',
 'Rushing_TD_y_y': 'RZ_Rush_TD',
 'Receiving_TGTS_y_y': 'RZ_Rec_Tgt',
 'Receiving_REC_y_y': 'RZ_Rec',
 'Receiving_YDS_y_y':'RZ_Rec_Yds',
 'Receiving_TD_y_y' : 'RZ_Rec_TD',
 'Fumbles_FUM_y': 'RZ_Fum',
 'Fumbles_LST_y': 'RZ_Fum_Lst',
 'PPG_y': 'RZ_PPG',
 'FPTS_y': 'RZ_FPTS'
 #'Bye',
 #'Pos_rk',
 #'Proj_Pts',
 #'ADP',
 #'Year'
                               })

# %%
df_2017.head()
# Out:
#                 Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0     Todd Gurley II  26.0          279         1305     4.7          13
# 1       Le'Veon Bell  28.5          321         1291     4.0           9
# 2       Alvin Kamara  25.1          120          728     6.1           8
# 3        Kareem Hunt  25.0          272         1327     4.9           8
# 4  Melvin Gordon III  27.3          284         1105     3.9           8
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum RZ_Fum_Lst  \
# 0          87      64         788          6  ...         4      1          1
# 1         106      85         655          2  ...         1      0          0
# 2         101      82         826          5  ...         4      0          0
# 3          63      53         455          3  ...         2      0          0
# 4          83      58         476          4  ...         4      0          0
#
#    RZ_PPG RZ_FPTS   Bye  Pos_rk Proj_Pts    ADP  Year
# ...

# %%
list(df_2017.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2017=df_2017.sort_values(by='FF_PPG', ascending=False)

# %%
df_2017
# Out:
#                Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0    Todd Gurley II  26.0          279         1305     4.7          13
# 1      Le'Veon Bell  28.5          321         1291     4.0           9
# 10  Ezekiel Elliott  25.1          242          983     4.1           7
# 2      Alvin Kamara  25.1          120          728     6.1           8
# 3       Kareem Hunt  25.0          272         1327     4.9           8
# ..              ...   ...          ...          ...     ...         ...
# 69   Branden Oliver  29.3           35           83     2.4           0
# 66    Elijhaa Penny  27.0           31          124     4.0           2
# 68     Paul Perkins  25.8           41           90     2.2           0
# 70      Terron Ward  28.5           30          129     4.3           0
# 71     James Conner  25.3           32          144     4.5           0
#
#     FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum  \
# ...

# %%
df_2017=df_2017.reset_index(drop=True)

# %%
df_2017
# Out:
#                Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0    Todd Gurley II  26.0          279         1305     4.7          13
# 1      Le'Veon Bell  28.5          321         1291     4.0           9
# 2   Ezekiel Elliott  25.1          242          983     4.1           7
# 3      Alvin Kamara  25.1          120          728     6.1           8
# 4       Kareem Hunt  25.0          272         1327     4.9           8
# ..              ...   ...          ...          ...     ...         ...
# 67   Branden Oliver  29.3           35           83     2.4           0
# 68    Elijhaa Penny  27.0           31          124     4.0           2
# 69     Paul Perkins  25.8           41           90     2.2           0
# 70      Terron Ward  28.5           30          129     4.3           0
# 71     James Conner  25.3           32          144     4.5           0
#
#     FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum  \
# ...

# %%
df_2017['PPG_RK']= df_2017.index + 1

# %%
df_2017.head()
# Out:
#               Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0   Todd Gurley II  26.0          279         1305     4.7          13
# 1     Le'Veon Bell  28.5          321         1291     4.0           9
# 2  Ezekiel Elliott  25.1          242          983     4.1           7
# 3     Alvin Kamara  25.1          120          728     6.1           8
# 4      Kareem Hunt  25.0          272         1327     4.9           8
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Fum RZ_Fum_Lst RZ_PPG  \
# 0          87      64         788          6  ...      1          1    8.1
# 1         106      85         655          2  ...      0          0    6.3
# 2          38      26         249          2  ...      0          0    5.9
# 3         101      82         826          5  ...      0          0    6.0
# 4          63      53         455          3  ...      0          0    3.7
#
#    RZ_FPTS   Bye  Pos_rk  Proj_Pts    ADP  Year PPG_RK
# ...

# %%
list(df_2018.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'Rushing_ATT_y_x',
#  'Rushing_YDS_y_x',
#  'Rushing_AVG_y_x',
#  'Rushing_TD_y_x',
#  'Receiving_TGTS_y_x',
#  'Receiving_REC_y_x',
#  'Receiving_YDS_y_x',
#  'Receiving_TD_y_x',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Rushing_ATT_x_y',
#  'Rushing_AVG_x_y',
#  'Rushing_TD_x_y',
#  'Receiving_TGTS_x_y',
#  'Receiving_REC_x_y',
#  'Receiving_YDS_x_y',
#  'Receiving_TD_x_y',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
# ...

# %%
df_2018.Rushing_ATT_x_x #Full Game
# Out:
# 0     219
# 1     261
# 2     256
# 3     194
# 4     304
#      ...
# 86     52
# 87     34
# 88     43
# 89     44
# 90     30
# Name: Rushing_ATT_x_x, Length: 91, dtype: int64

# %%
df_2018.Rushing_ATT_y_x #Full Game Drop
# Out:
# 0     219
# 1     261
# 2     256
# 3     194
# 4     304
#      ...
# 86     52
# 87     34
# 88     43
# 89     44
# 90     30
# Name: Rushing_ATT_y_x, Length: 91, dtype: int64

# %%
df_2018.Rushing_ATT_x_y #Full Game Drop
# Out:
# 0     219
# 1     261
# 2     256
# 3     194
# 4     304
#      ...
# 86     52
# 87     34
# 88     43
# 89     44
# 90     30
# Name: Rushing_ATT_x_y, Length: 91, dtype: int64

# %%
df_2018.Rushing_ATT_y_y #RZ
# Out:
# 0     46
# 1     50
# 2     64
# 3     52
# 4     39
#       ..
# 86     8
# 87     1
# 88     8
# 89     5
# 90     7
# Name: Rushing_ATT_y_y, Length: 91, dtype: int64

# %%
df_2018=df_2018.drop(columns=['Rushing_ATT_y_x',
 'Rushing_YDS_y_x',
 'Rushing_AVG_y_x',
 'Rushing_TD_y_x',
 'Receiving_TGTS_y_x',
 'Receiving_REC_y_x',
 'Receiving_YDS_y_x',
 'Receiving_TD_y_x',
 'Rushing_ATT_x_y',
 'Rushing_AVG_x_y',
 'Rushing_TD_x_y',
 'Receiving_TGTS_x_y',
 'Receiving_REC_x_y',
 'Receiving_YDS_x_y',
 'Receiving_TD_x_y',])

# %%
list(df_2018.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_AVG_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Age_y',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2018.PPG_x
# Out:
# 0     24.1
# 1     24.1
# 2     26.6
# 3     23.6
# 4     21.9
#       ...
# 86     3.5
# 87     4.3
# 88     3.3
# 89     2.1
# 90     1.1
# Name: PPG_x, Length: 91, dtype: float64

# %%
df_2018.PPG_y
# Out:
# 0      6.6
# 1      5.5
# 2     11.7
# 3     10.3
# 4      4.6
#       ...
# 86     0.4
# 87     0.0
# 88     1.0
# 89     0.5
# 90     0.2
# Name: PPG_y, Length: 91, dtype: float64

# %%
df_2018=df_2018.drop(columns='Age_y')

# %%
list(df_2018.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_AVG_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2018=df_2018.drop(columns='Rushing_AVG_y_y')

# %%
list(df_2018.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2018.Fumbles_FUM_x
# Out:
# 0     4
# 1     0
# 2     1
# 3     1
# 4     6
#      ..
# 86    1
# 87    1
# 88    0
# 89    0
# 90    1
# Name: Fumbles_FUM_x, Length: 91, dtype: int64

# %%
df_2018.Fumbles_FUM_y
# Out:
# 0     2
# 1     0
# 2     0
# 3     0
# 4     2
#      ..
# 86    0
# 87    0
# 88    0
# 89    0
# 90    0
# Name: Fumbles_FUM_y, Length: 91, dtype: int64

# %%
list(df_2017.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year',
#  'PPG_RK']

# %%
df_2018=df_2018.rename(columns={'name':'Name',
 'Age_x':'Age',
 'Rushing_ATT_x_x': 'FF_Rush_Att',
 'Rushing_YDS_x': 'FF_Rush_Yds',
 'Rushing_AVG_x_x': 'FF_Ypc',
 'Rushing_TD_x_x': 'FF_Rush_TD',
 'Receiving_TGTS_x_x': 'FF_Rec_Tgt',
 'Receiving_REC_x_x': 'FF_Rec',
 'Receiving_YDS_x_x': 'FF_Rec_Yds',
 'Receiving_TD_x_x': 'FF_Rec_TD',
 #'Snapshare',
 'OppShare': 'Opp_Share',
 #'Shotgun_PCT',
 #'Shotgun_YPC',
 'Un_Center_PCT' :'Under Center_PCT',
 'Un_Center_YPC': 'Under Center_YPC',
 'Box_Front_Avf ': 'Box_Front',
 'Stacked_PCT': 'Stacked_Front',
 'Base_PCT': 'Base_Front',
 'Light_PCT': 'Light_Front',
 #'JukeRate',
 #'Tck_Evad',
 #'Tot_Yds_Ctd',
 #'Yds_Ctd_GM',
 #'Breakaway_TOT',
 #'Breakaway_Rate',
 #'Fan_Pts_Tgt',
 #'Fan_Pts_Opp',
 #'Tot_Dps',
 #'Drops_Rate',
 'Fumbles_FUM_x': 'FF_Fum',
 'Fumbles_LST_x': 'FF_Fum_Lst',
 'PPG_x':'FF_PPG',
 'FPTS_x':'FF_FPTS',
 #'GMS',
 'Rushing_ATT_y_y': 'RZ_Rush_Att',
 'Rushing_YDS_y_y': 'RZ_Rush_Yds',
 'Rushing_TD_y_y': 'RZ_Rush_TD',
 'Receiving_TGTS_y_y': 'RZ_Rec_Tgt',
 'Receiving_REC_y_y' : 'RZ_Rec',
 'Receiving_YDS_y_y': 'RZ_Rec_Yds',
 'Receiving_TD_y_y': 'RZ_Rec_TD',
 'Fumbles_FUM_y' : 'RZ_Fum',
 'Fumbles_LST_y': 'RZ_Fum_Lst',
 'PPG_y': 'RZ_PPG',
 'FPTS_y': 'RZ_FPTS'
 #'Bye',
 #'Pos_rk',
 #'Proj_Pts',
 #'ADP',
 #'Year'
                               })

# %%
df_2018.head()
# Out:
#                   Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0  Christian McCaffrey  24.2          219         1098     5.0           7
# 1       Saquon Barkley  23.5          261         1307     5.0          11
# 2       Todd Gurley II  26.0          256         1251     4.9          17
# 3         Alvin Kamara  25.1          194          883     4.6          14
# 4      Ezekiel Elliott  25.1          304         1435     4.7           6
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum RZ_Fum_Lst  \
# 0         124     107         867          6  ...         5      2          1
# 1         121      91         721          4  ...         3      0          0
# 2          81      59         580          4  ...         3      0          0
# 3         105      81         709          4  ...         3      0          0
# 4          95      77         567          3  ...         2      2          1
#
# ...

# %%
list(df_2018.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2018=df_2018.sort_values(by='FF_PPG', ascending=False)

# %%
df_2018=df_2018.reset_index(drop=True)

# %%
df_2018['PPG_RK']= df_2018.index + 1

# %%
df_2018.head()
# Out:
#                   Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0       Todd Gurley II  26.0          256         1251     4.9          17
# 1  Christian McCaffrey  24.2          219         1098     5.0           7
# 2       Saquon Barkley  23.5          261         1307     5.0          11
# 3         Alvin Kamara  25.1          194          883     4.6          14
# 4    Melvin Gordon III  27.3          175          885     5.1          10
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Fum RZ_Fum_Lst RZ_PPG  \
# 0          81      59         580          4  ...      0          0   11.7
# 1         124     107         867          6  ...      2          1    6.6
# 2         121      91         721          4  ...      0          0    5.5
# 3         105      81         709          4  ...      0          0   10.3
# 4          66      50         490          4  ...      2          0    7.9
#
#    RZ_FPTS   Bye  Pos_rk  Proj_Pts   ADP  Year PPG_RK
# ...

# %%
df_2019
# Out:
#                      name  Age_x  Rushing_ATT_x_x  Rushing_YDS_x  \
# 0     Christian McCaffrey   24.2              287           1387
# 1             Aaron Jones   25.7              236           1084
# 2         Ezekiel Elliott   25.1              301           1357
# 3           Austin Ekeler   25.3              132            557
# 4             Dalvin Cook   25.0              250           1135
# ..                    ...    ...              ...            ...
# 74      Jonathan Williams   26.5               49            235
# 75           Bilal Powell   31.8               59            229
# 76          Ty Montgomery   27.6               32            103
# 77        Darwin Thompson   23.5               38            128
# 78  Darrell Henderson Jr.   23.0               39            147
#
#     Rushing_AVG_x_x  Rushing_TD_x_x  Receiving_TGTS_x_x  Receiving_REC_x_x  \
# 0               4.8              15                 143                116
# ...

# %%
list(df_2019.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'Rushing_ATT_y_x',
#  'Rushing_YDS_y_x',
#  'Rushing_AVG_y_x',
#  'Rushing_TD_y_x',
#  'Receiving_TGTS_y_x',
#  'Receiving_REC_y_x',
#  'Receiving_YDS_y_x',
#  'Receiving_TD_y_x',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Rushing_ATT_x_y',
#  'Rushing_AVG_x_y',
#  'Rushing_TD_x_y',
#  'Receiving_TGTS_x_y',
#  'Receiving_REC_x_y',
#  'Receiving_YDS_x_y',
#  'Receiving_TD_x_y',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
# ...

# %%
df_2019.Rushing_ATT_x_x #Full Game
# Out:
# 0     287
# 1     236
# 2     301
# 3     132
# 4     250
#      ...
# 74     49
# 75     59
# 76     32
# 77     38
# 78     39
# Name: Rushing_ATT_x_x, Length: 79, dtype: int64

# %%
df_2019.Rushing_ATT_y_x #Full Game Drop
# Out:
# 0     287
# 1     236
# 2     301
# 3     132
# 4     250
#      ...
# 74     49
# 75     59
# 76     32
# 77     38
# 78     39
# Name: Rushing_ATT_y_x, Length: 79, dtype: int64

# %%
df_2019.Rushing_ATT_x_y #Full Game Drop
# Out:
# 0     287
# 1     236
# 2     301
# 3     132
# 4     250
#      ...
# 74     49
# 75     59
# 76     32
# 77     37
# 78     39
# Name: Rushing_ATT_x_y, Length: 79, dtype: int64

# %%
df_2019.Rushing_ATT_y_y #RZ
# Out:
# 0     56
# 1     34
# 2     60
# 3     17
# 4     46
#       ..
# 74     8
# 75     5
# 76     1
# 77    10
# 78     2
# Name: Rushing_ATT_y_y, Length: 79, dtype: int64

# %%
df_2019=df_2019.drop(columns=['Rushing_ATT_y_x',
 'Rushing_YDS_y_x',
 'Rushing_AVG_y_x',
 'Rushing_TD_y_x',
 'Receiving_TGTS_y_x',
 'Receiving_REC_y_x',
 'Receiving_YDS_y_x',
 'Receiving_TD_y_x',
 'Rushing_ATT_x_y',
 'Rushing_AVG_x_y',
 'Rushing_TD_x_y',
 'Receiving_TGTS_x_y',
 'Receiving_REC_x_y',
 'Receiving_YDS_x_y',
 'Receiving_TD_x_y',])

# %%
list(df_2019.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_AVG_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Age_y',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2019.PPG_x
# Out:
# 0     29.4
# 1     19.7
# 2     19.5
# 3     19.3
# 4     20.9
#       ...
# 74     4.5
# 75     2.6
# 76     2.0
# 77     2.7
# 78     1.7
# Name: PPG_x, Length: 79, dtype: float64

# %%
df_2019.PPG_y
# Out:
# 0     7.4
# 1     7.3
# 2     6.7
# 3     3.6
# 4     6.3
#      ...
# 74    0.9
# 75    0.1
# 76    0.2
# 77    0.8
# 78    0.0
# Name: PPG_y, Length: 79, dtype: float64

# %%
df_2019=df_2019.drop(columns='Age_y')

# %%
list(df_2019.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_AVG_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2019=df_2019.drop(columns='Rushing_AVG_y_y')

# %%
list(df_2019.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2019.Fumbles_FUM_x
# Out:
# 0     1
# 1     3
# 2     3
# 3     3
# 4     4
#      ..
# 74    0
# 75    0
# 76    0
# 77    0
# 78    0
# Name: Fumbles_FUM_x, Length: 79, dtype: int64

# %%
df_2019.Fumbles_FUM_y
# Out:
# 0     0
# 1     0
# 2     0
# 3     2
# 4     0
#      ..
# 74    0
# 75    0
# 76    0
# 77    0
# 78    0
# Name: Fumbles_FUM_y, Length: 79, dtype: int64

# %%
list(df_2018.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year',
#  'PPG_RK']

# %%
list(df_2019.columns)
# Out:
# ['name',
#  'Age_x',
#  'Rushing_ATT_x_x',
#  'Rushing_YDS_x',
#  'Rushing_AVG_x_x',
#  'Rushing_TD_x_x',
#  'Receiving_TGTS_x_x',
#  'Receiving_REC_x_x',
#  'Receiving_YDS_x_x',
#  'Receiving_TD_x_x',
#  'Snapshare',
#  'OppShare',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Un_Center_PCT',
#  'Un_Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_PCT',
#  'Base_PCT',
#  'Light_PCT',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'Fumbles_FUM_x',
#  'Fumbles_LST_x',
#  'PPG_x',
#  'FPTS_x',
#  'GMS',
#  'Rushing_ATT_y_y',
#  'Rushing_YDS_y_y',
#  'Rushing_TD_y_y',
#  'Receiving_TGTS_y_y',
#  'Receiving_REC_y_y',
#  'Receiving_YDS_y_y',
#  'Receiving_TD_y_y',
#  'Fumbles_FUM_y',
#  'Fumbles_LST_y',
#  'PPG_y',
#  'FPTS_y',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
list(df_2018.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year',
#  'PPG_RK']

# %%
df_2019=df_2019.rename(columns={'name' :'Name',
 'Age_x' : 'Age',
 'Rushing_ATT_x_x': 'FF_Rush_Att',
 'Rushing_YDS_x': 'FF_Rush_Yds',
 'Rushing_AVG_x_x': 'FF_Ypc',
 'Rushing_TD_x_x': 'FF_Rush_TD',
 'Receiving_TGTS_x_x': 'FF_Rec_Tgt',
 'Receiving_REC_x_x':  'FF_Rec',
 'Receiving_YDS_x_x': 'FF_Rec_Yds',
 'Receiving_TD_x_x': 'FF_Rec_TD',
 #'Snapshare',
 'OppShare':  'Opp_Share',
 #'Shotgun_PCT',
 #'Shotgun_YPC',
 'Un_Center_PCT':'Under Center_PCT',
 'Un_Center_YPC': 'Under Center_YPC',
 'Box_Front_Avf':'Box_Front',
 'Stacked_PCT': 'Stacked_Front',
 'Base_PCT': 'Base_Front',
 'Light_PCT': 'Light_Front',
 #'JukeRate',
# 'Tck_Evad',
 #'Tot_Yds_Ctd',
# 'Yds_Ctd_GM',
# 'Breakaway_TOT',
 #'Breakaway_Rate',
 #'Fan_Pts_Att',
# 'Fan_Pts_Tgt',
# 'Fan_Pts_Opp',
 #'Tot_Dps',
# 'Drops_Rate',
 'Fumbles_FUM_x': 'FF_Fum',
 'Fumbles_LST_x': 'FF_Fum_Lst',
 'PPG_x': 'FF_PPG',
 'FPTS_x':'FF_FPTS',
 #'GMS',
 'Rushing_ATT_y_y': 'RZ_Rush_Att',
 'Rushing_YDS_y_y': 'RZ_Rush_Yds',
 'Rushing_TD_y_y': 'RZ_Rush_TD',
 'Receiving_TGTS_y_y': 'RZ_Rec_Tgt',
 'Receiving_REC_y_y': 'RZ_Rec',
 'Receiving_YDS_y_y': 'RZ_Rec_Yds',
 'Receiving_TD_y_y': 'RZ_Rec_TD',
 'Fumbles_FUM_y': 'RZ_Fum',
 'Fumbles_LST_y':'RZ_Fum_Lst',
 'PPG_y': 'RZ_PPG',
 'FPTS_y':'RZ_FPTS'
 #'Bye',
 #'Pos_rk',
 #'Proj_Pts',
 #'ADP',
 #'Year'
                               })

# %%
df_2019.head()
# Out:
#                   Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0  Christian McCaffrey  24.2          287         1387     4.8          15
# 1          Aaron Jones  25.7          236         1084     4.6          16
# 2      Ezekiel Elliott  25.1          301         1357     4.5          12
# 3        Austin Ekeler  25.3          132          557     4.2           3
# 4          Dalvin Cook  25.0          250         1135     4.5          13
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum RZ_Fum_Lst  \
# 0         143     116        1005          4  ...         3      0          0
# 1          69      49         474          3  ...         1      0          0
# 2          72      54         419          2  ...         2      0          0
# 3         108      92         993          8  ...         4      2          2
# 4          63      53         519          0  ...         0      0          0
#
# ...

# %%
list(df_2019.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front_Avf ',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year']

# %%
df_2019=df_2019.rename(columns={'Box_Front_Avf ': 'Box_Front', 
                             'RZ_Rec_tD': 'RZ_Rec_TD'})

# %%
df_2019.head()
# Out:
#                   Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0  Christian McCaffrey  24.2          287         1387     4.8          15
# 1          Aaron Jones  25.7          236         1084     4.6          16
# 2      Ezekiel Elliott  25.1          301         1357     4.5          12
# 3        Austin Ekeler  25.3          132          557     4.2           3
# 4          Dalvin Cook  25.0          250         1135     4.5          13
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum RZ_Fum_Lst  \
# 0         143     116        1005          4  ...         3      0          0
# 1          69      49         474          3  ...         1      0          0
# 2          72      54         419          2  ...         2      0          0
# 3         108      92         993          8  ...         4      2          2
# 4          63      53         519          0  ...         0      0          0
#
# ...

# %%
list(df_2018.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Shotgun_YPC',
#  'Under Center_PCT',
#  'Under Center_YPC',
#  'Box_Front',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Bye',
#  'Pos_rk',
#  'Proj_Pts',
#  'ADP',
#  'Year',
#  'PPG_RK']

# %%
df_2017.head()
# Out:
#                 Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0     Todd Gurley II  26.0          279         1305     4.7          13
# 1       Le'Veon Bell  28.5          321         1291     4.0           9
# 2       Alvin Kamara  25.1          120          728     6.1           8
# 3        Kareem Hunt  25.0          272         1327     4.9           8
# 4  Melvin Gordon III  27.3          284         1105     3.9           8
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_TD RZ_Fum RZ_Fum_Lst  \
# 0          87      64         788          6  ...         4      1          1
# 1         106      85         655          2  ...         1      0          0
# 2         101      82         826          5  ...         4      0          0
# 3          63      53         455          3  ...         2      0          0
# 4          83      58         476          4  ...         4      0          0
#
#    RZ_PPG RZ_FPTS   Bye  Pos_rk Proj_Pts    ADP  Year
# ...

# %%
df_2019=df_2019.sort_values(by='FF_PPG', ascending=False)

# %%
df_2019=df_2019.reset_index(drop=True)

# %%
df_2019['PPG_RK']= df_2019.index + 1

# %%
df_2019.head()
# Out:
#                   Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0  Christian McCaffrey  24.2          287         1387     4.8          15
# 1          Dalvin Cook  25.0          250         1135     4.5          13
# 2          Aaron Jones  25.7          236         1084     4.6          16
# 3      Ezekiel Elliott  25.1          301         1357     4.5          12
# 4        Austin Ekeler  25.3          132          557     4.2           3
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Fum RZ_Fum_Lst RZ_PPG  \
# 0         143     116        1005          4  ...      0          0    7.4
# 1          63      53         519          0  ...      0          0    6.3
# 2          69      49         474          3  ...      0          0    7.3
# 3          72      54         419          2  ...      0          0    6.7
# 4         108      92         993          8  ...      2          2    3.6
#
#    RZ_FPTS   Bye  Pos_rk  Proj_Pts   ADP  Year PPG_RK
# ...

# %%
df_2018.head()
# Out:
#                   Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0       Todd Gurley II  26.0          256         1251     4.9          17
# 1  Christian McCaffrey  24.2          219         1098     5.0           7
# 2       Saquon Barkley  23.5          261         1307     5.0          11
# 3         Alvin Kamara  25.1          194          883     4.6          14
# 4    Melvin Gordon III  27.3          175          885     5.1          10
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Fum RZ_Fum_Lst RZ_PPG  \
# 0          81      59         580          4  ...      0          0   11.7
# 1         124     107         867          6  ...      2          1    6.6
# 2         121      91         721          4  ...      0          0    5.5
# 3         105      81         709          4  ...      0          0   10.3
# 4          66      50         490          4  ...      2          0    7.9
#
#    RZ_FPTS   Bye  Pos_rk  Proj_Pts   ADP  Year PPG_RK
# ...

# %%
df_2017.head()
# Out:
#               Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0   Todd Gurley II  26.0          279         1305     4.7          13
# 1     Le'Veon Bell  28.5          321         1291     4.0           9
# 2  Ezekiel Elliott  25.1          242          983     4.1           7
# 3     Alvin Kamara  25.1          120          728     6.1           8
# 4      Kareem Hunt  25.0          272         1327     4.9           8
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Fum RZ_Fum_Lst RZ_PPG  \
# 0          87      64         788          6  ...      1          1    8.1
# 1         106      85         655          2  ...      0          0    6.3
# 2          38      26         249          2  ...      0          0    5.9
# 3         101      82         826          5  ...      0          0    6.0
# 4          63      53         455          3  ...      0          0    3.7
#
#    RZ_FPTS   Bye  Pos_rk  Proj_Pts    ADP  Year PPG_RK
# ...

# %%
df_comb = [df_2017, df_2018, df_2019]

df_final =pd.concat(df_comb)

# %%
df_final
# Out:
#                      Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0          Todd Gurley II  26.0          279         1305     4.7          13
# 1            Le'Veon Bell  28.5          321         1291     4.0           9
# 2         Ezekiel Elliott  25.1          242          983     4.1           7
# 3            Alvin Kamara  25.1          120          728     6.1           8
# 4             Kareem Hunt  25.0          272         1327     4.9           8
# ..                    ...   ...          ...          ...     ...         ...
# 74           Justice Hill  22.8           58          225     3.9           2
# 75        Darwin Thompson  23.5           38          128     3.4           1
# 76           Bilal Powell  31.8           59          229     3.9           0
# 77          Ty Montgomery  27.6           32          103     3.2           0
# 78  Darrell Henderson Jr.  23.0           39          147     3.8           0
#
# ...

# %%
df_final= df_final.drop(['Bye', 'Proj_Pts'], axis = 1)

# %%
df_final
# Out:
#                      Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0          Todd Gurley II  26.0          279         1305     4.7          13
# 1            Le'Veon Bell  28.5          321         1291     4.0           9
# 2         Ezekiel Elliott  25.1          242          983     4.1           7
# 3            Alvin Kamara  25.1          120          728     6.1           8
# 4             Kareem Hunt  25.0          272         1327     4.9           8
# ..                    ...   ...          ...          ...     ...         ...
# 74           Justice Hill  22.8           58          225     3.9           2
# 75        Darwin Thompson  23.5           38          128     3.4           1
# 76           Bilal Powell  31.8           59          229     3.9           0
# 77          Ty Montgomery  27.6           32          103     3.2           0
# 78  Darrell Henderson Jr.  23.0           39          147     3.8           0
#
# ...

# %%
df_final.isnull().values.any()
# Out:
# True

# %%
df_final.isnull().sum()
# Out:
# Name                 0
# Age                  0
# FF_Rush_Att          0
# FF_Rush_Yds          0
# FF_Ypc               1
# FF_Rush_TD           0
# FF_Rec_Tgt           0
# FF_Rec               0
# FF_Rec_Yds           0
# FF_Rec_TD            0
# Snapshare            0
# Opp_Share            0
# Shotgun_PCT          0
# Shotgun_YPC         75
# Under Center_PCT     0
# Under Center_YPC    73
# Box_Front           73
# Stacked_Front        0
# Base_Front           0
# Light_Front          0
# JukeRate             0
# Tck_Evad             1
# Tot_Yds_Ctd          2
# Yds_Ctd_GM           2
# Breakaway_TOT        1
# Breakaway_Rate       0
# Fan_Pts_Att          0
# Fan_Pts_Tgt          0
# Fan_Pts_Opp          1
# Tot_Dps              0
# Drops_Rate           0
# FF_Fum               0
# FF_Fum_Lst           0
# FF_PPG               0
# FF_FPTS              0
# GMS                  0
# RZ_Rush_Att          0
# RZ_Rush_Yds          0
# RZ_Rush_TD           0
# RZ_Rec_Tgt           0
# ...

# %%
df_final=df_final.drop(columns=['Shotgun_YPC', 'Under Center_YPC', 'Box_Front'])

# %%
df_final
# Out:
#                      Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0          Todd Gurley II  26.0          279         1305     4.7          13
# 1            Le'Veon Bell  28.5          321         1291     4.0           9
# 2         Ezekiel Elliott  25.1          242          983     4.1           7
# 3            Alvin Kamara  25.1          120          728     6.1           8
# 4             Kareem Hunt  25.0          272         1327     4.9           8
# ..                    ...   ...          ...          ...     ...         ...
# 74           Justice Hill  22.8           58          225     3.9           2
# 75        Darwin Thompson  23.5           38          128     3.4           1
# 76           Bilal Powell  31.8           59          229     3.9           0
# 77          Ty Montgomery  27.6           32          103     3.2           0
# 78  Darrell Henderson Jr.  23.0           39          147     3.8           0
#
# ...

# %%
df_final=df_final.dropna()

# %%
df_final
# Out:
#                      Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0          Todd Gurley II  26.0          279         1305     4.7          13
# 1            Le'Veon Bell  28.5          321         1291     4.0           9
# 2         Ezekiel Elliott  25.1          242          983     4.1           7
# 3            Alvin Kamara  25.1          120          728     6.1           8
# 4             Kareem Hunt  25.0          272         1327     4.9           8
# ..                    ...   ...          ...          ...     ...         ...
# 74           Justice Hill  22.8           58          225     3.9           2
# 75        Darwin Thompson  23.5           38          128     3.4           1
# 76           Bilal Powell  31.8           59          229     3.9           0
# 77          Ty Montgomery  27.6           32          103     3.2           0
# 78  Darrell Henderson Jr.  23.0           39          147     3.8           0
#
# ...

# %%
df_final.isnull().values.any()
# Out:
# False

# %%
list(df_final.columns)
# Out:
# ['Name',
#  'Age',
#  'FF_Rush_Att',
#  'FF_Rush_Yds',
#  'FF_Ypc',
#  'FF_Rush_TD',
#  'FF_Rec_Tgt',
#  'FF_Rec',
#  'FF_Rec_Yds',
#  'FF_Rec_TD',
#  'Snapshare',
#  'Opp_Share',
#  'Shotgun_PCT',
#  'Under Center_PCT',
#  'Stacked_Front',
#  'Base_Front',
#  'Light_Front',
#  'JukeRate',
#  'Tck_Evad',
#  'Tot_Yds_Ctd',
#  'Yds_Ctd_GM',
#  'Breakaway_TOT',
#  'Breakaway_Rate',
#  'Fan_Pts_Att',
#  'Fan_Pts_Tgt',
#  'Fan_Pts_Opp',
#  'Tot_Dps',
#  'Drops_Rate',
#  'FF_Fum',
#  'FF_Fum_Lst',
#  'FF_PPG',
#  'FF_FPTS',
#  'GMS',
#  'RZ_Rush_Att',
#  'RZ_Rush_Yds',
#  'RZ_Rush_TD',
#  'RZ_Rec_Tgt',
#  'RZ_Rec',
#  'RZ_Rec_Yds',
#  'RZ_Rec_TD',
#  'RZ_Fum',
#  'RZ_Fum_Lst',
#  'RZ_PPG',
#  'RZ_FPTS',
#  'Pos_rk',
#  'ADP',
#  'Year',
#  'PPG_RK']

# %%
df_final=df_final.drop(columns=['GMS'], axis=1)
df_final
# Out:
#                      Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0          Todd Gurley II  26.0          279         1305     4.7          13
# 1            Le'Veon Bell  28.5          321         1291     4.0           9
# 2         Ezekiel Elliott  25.1          242          983     4.1           7
# 3            Alvin Kamara  25.1          120          728     6.1           8
# 4             Kareem Hunt  25.0          272         1327     4.9           8
# ..                    ...   ...          ...          ...     ...         ...
# 74           Justice Hill  22.8           58          225     3.9           2
# 75        Darwin Thompson  23.5           38          128     3.4           1
# 76           Bilal Powell  31.8           59          229     3.9           0
# 77          Ty Montgomery  27.6           32          103     3.2           0
# 78  Darrell Henderson Jr.  23.0           39          147     3.8           0
#
# ...

# %%
posrk='RB11'

remove_RB=posrk[2:]

remove_RB
# Out:
# '11'

# %%
(int('11'))
# Out:
# 11

# %%
int(posrk[2:])
# Out:
# 11

# %%
df_final['Pos_rk'].apply(lambda pos_rk: int(pos_rk[2:]))
# Out:
# 0     11
# 1      2
# 2      3
# 3     52
# 4     10
#       ..
# 74    49
# 75    39
# 76    75
# 77    59
# 78    41
# Name: Pos_rk, Length: 240, dtype: int64

# %%
df_final['Pos_rk']=df_final['Pos_rk'].apply(lambda pos_rk: int(pos_rk[2:]))

# %%
df_final
# Out:
#                      Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0          Todd Gurley II  26.0          279         1305     4.7          13
# 1            Le'Veon Bell  28.5          321         1291     4.0           9
# 2         Ezekiel Elliott  25.1          242          983     4.1           7
# 3            Alvin Kamara  25.1          120          728     6.1           8
# 4             Kareem Hunt  25.0          272         1327     4.9           8
# ..                    ...   ...          ...          ...     ...         ...
# 74           Justice Hill  22.8           58          225     3.9           2
# 75        Darwin Thompson  23.5           38          128     3.4           1
# 76           Bilal Powell  31.8           59          229     3.9           0
# 77          Ty Montgomery  27.6           32          103     3.2           0
# 78  Darrell Henderson Jr.  23.0           39          147     3.8           0
#
# ...

# %%
df_final.head()
# Out:
#               Name   Age  FF_Rush_Att  FF_Rush_Yds  FF_Ypc  FF_Rush_TD  \
# 0   Todd Gurley II  26.0          279         1305     4.7          13
# 1     Le'Veon Bell  28.5          321         1291     4.0           9
# 2  Ezekiel Elliott  25.1          242          983     4.1           7
# 3     Alvin Kamara  25.1          120          728     6.1           8
# 4      Kareem Hunt  25.0          272         1327     4.9           8
#
#    FF_Rec_Tgt  FF_Rec  FF_Rec_Yds  FF_Rec_TD  ... RZ_Rec_Yds RZ_Rec_TD RZ_Fum  \
# 0          87      64         788          6  ...         52         4      1
# 1         106      85         655          2  ...         50         1      0
# 2          38      26         249          2  ...         15         1      0
# 3         101      82         826          5  ...         94         4      0
# 4          63      53         455          3  ...         12         2      0
#
#   RZ_Fum_Lst RZ_PPG RZ_FPTS Pos_rk    ADP  Year  PPG_RK
# ...

# %%
# order data frame by FF_PPG

#new column that is 1 through whatever

# %%
with open('./pickles/df_final.p', 'wb') as write_file:
    pickle.dump(df_final, write_file)

# %%
#Target Variable

# %%
#Drop NAN

# %%
#Pickle Again

# %%
#Start Modeling Notebook

# %%
#First
